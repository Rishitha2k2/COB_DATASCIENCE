# %% [markdown]
# # Import all required Libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# # Call API and data through API

# %%
api_url = "https://api.binance.com/api/v3/ticker/24hr"
response = requests.get(api_url)

# %%
#Put If-else statement on called API
if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
    df.to_csv("task1.csv", index=False)  # This will create a CSV file named "task.csv" in the current directory
else:
    print("API request to task1 failed")

# %%
#Assign variable to CSV file
data=pd.read_csv("task1.csv")

# %%
data
# Out:
#           symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0         ETHBTC    -0.000090              -0.165          0.054326
# 1         LTCBTC     0.000008               0.373          0.002143
# 2         BNBBTC    -0.000156              -2.116          0.007271
# 3         NEOBTC    -0.000003              -1.076          0.000230
# 4        QTUMETH     0.000032               2.356          0.001386
# ...          ...          ...                 ...               ...
# 2317   AVAXFDUSD     0.220000               2.450          9.213071
# 2318     BANDTRY    -0.830000              -2.020         39.616463
# 2319    BCHFDUSD    11.600000               5.039        237.415409
# 2320     LOOMTRY     0.464000              15.874          3.205123
# 2321  MATICFDUSD     0.023100               4.486          0.530551
#
#       prevClosePrice   lastPrice   lastQty    bidPrice      bidQty  \
# 0           0.054440    0.054350    0.1105    0.054340     58.1402
# 1           0.002145    0.002152    0.3720    0.002151      6.4160
# 2           0.007371    0.007216    0.4690    0.007216     10.9540
# 3           0.000232    0.000230    0.7100    0.000230     80.1100
# 4           0.001362    0.001390   62.1000    0.001388     61.4000
# ...              ...         ...       ...         ...         ...
# 2317        8.980000    9.200000    0.9200    9.180000     10.8900
# 2318       41.050000   40.250000  284.0000   40.190000    332.5000
# 2319      229.900000  241.800000    2.4870  242.900000      0.4110
# 2320        2.921000    3.387000    8.0000    3.390000  18723.0000
# 2321        0.513200    0.538000   18.9000    0.536900    186.2000
#
#         askPrice  ...   openPrice   highPrice    lowPrice        volume  \
# 0       0.054350  ...    0.054440    0.054830    0.053880  4.249266e+04
# 1       0.002152  ...    0.002144    0.002160    0.002121  3.799747e+04
# 2       0.007217  ...    0.007372    0.007382    0.007150  3.715844e+04
# 3       0.000230  ...    0.000232    0.000232    0.000227  3.025264e+04
# 4       0.001396  ...    0.001358    0.001400    0.001352  1.252400e+03
# ...          ...  ...         ...         ...         ...           ...
# 2317    9.210000  ...    8.980000    9.350000    8.940000  4.860400e+02
# 2318   40.250000  ...   41.080000   41.770000   38.180000  9.317369e+05
# 2319  243.500000  ...  230.200000  256.600000  227.700000  1.138400e+02
# 2320    3.392000  ...    2.923000    3.771000    2.658000  1.811292e+08
# 2321    0.539300  ...    0.514900    0.545400    0.514000  3.890200e+04
#
#        quoteVolume       openTime      closeTime    firstId     lastId   count
# 0     2.308436e+03  1697729087630  1697815487630  424086853  424140257   53405
# 1     8.142504e+01  1697729084007  1697815484007   93822763   93832161    9399
# 2     2.701964e+02  1697729078826  1697815478826  227895091  227933968   38878
# 3     6.953919e+00  1697729087121  1697815487121   45562564   45564255    1692
# 4     1.736380e+00  1697728996920  1697815396920    5404054    5404100      47
# ...            ...            ...            ...        ...        ...     ...
# 2317  4.477921e+03  1697729073509  1697815473509         35        102      68
# 2318  3.691212e+07  1697729086385  1697815486385       8573      16221    7649
# 2319  2.702737e+04  1697729088262  1697815488262         14        178     165
# 2320  5.805412e+08  1697729088797  1697815488797      37749     138077  100329
# 2321  2.063949e+04  1697729088483  1697815488483         30        227     198
#
# [2322 rows x 21 columns]
